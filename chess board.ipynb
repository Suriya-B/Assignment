# %%
def ValidChessBoard(ChessBoard):
    
    
    chessboardvalues=[]
    a=['a','b','c','d','e','f','g','h']
    for i in range(1,9):       
        for j in a:
            chessboardvalues.append(str(i)+j)
    chessboardcoins=[]
    a=['w','b']
    b=['king','queen','bishop','knight','rook','pawn']
    for i in a:
        for j in b:
            chessboardcoins.append(i+j)
    
    keys=list(ChessBoard.keys())
    print(keys)
    
    keycount=len(keys)
    valuablekey=0
    
    for i in range(keycount):
        if keys[i] in chessboardvalues:
            valuablekey+=1
        else:
            print('the chess board values doesn\'t match the correct board values')
            break
    #checking if the board have same key values
    correct_keyvalues=0
    

            
            
    if keycount==valuablekey:
        values=list(ChessBoard.values())
        valuecount=len(values)
        correctvalues=0
        for i in range(valuecount):
            if values[i] in chessboardcoins:
                correctvalues+=1
            else:
                print('the chess board coins doesn\'t match the correct values')
                break
                
        if valuecount==correctvalues:
            coincount={}
            for coinname in values:
                coincount.setdefault(coinname, 0)
                coincount[coinname]=coincount[coinname]+1
                print (coincount)
            if 'wking' in coincount.keys() and 'bking' in coincount.keys():
                if coincount['wking']==1 and coincount['bking']==1:
                    for i in coincount.keys():
                        if i=='wqueen':
                            if coincount['wqueen']==1:
                                print('the chess board contains one wqueen coin')
                            else:
                                print('the chess board contains %s wqueen coins,the chess board is invalid'%(coincount['wqueen']))
                                break
                        if i=='bqueen':
                            if coincount['bqueen']==1:
                                print('the chess board contains one bqueen coin')
                            else:
                                print('the chess board contains %s bqueen coins,the chess board is invalid'%(coincount['wqueen']))
                                break
                        if i=='wbishop':
                            if coincount['wbishop']<=2:
                                print('the chess board contains %s wbishop in chess board'%(coincount['wbishop']))
                            else:
                                print('the chess board contains %s wbishop in chess board,the chess board is invalid'%(coincount['wbishop']))
                                break
                        if i=='bbishop':
                            if coincount['bbishop']<=2:
                                print('the chess board contains %s bbishop in chess board'%(coincount['bbishop']))
                            else:
                                print('the chess board contains %s bbishop in chess board,the chess board is invalid'%(coincount['bbishop']))
                                break
                        if i=='wknight':
                            if coincount['wknight']<=2:
                                print('the chess board contains %s wknight in chess board'%(coincount['wknight']))
                            else:
                                print('the chess board contains %s wknight in chess board,the chess board is invalid'%(coincount['wknight']))
                                break
                        if i=='bknight':
                            if coincount['bknight']<=2:
                                print('the chess board contains %s bknight in chess board'%(coincount['bknight']))
                            else:
                                print('the chess board contains %s bknight in chess board,the chess board is invalid'%(coincount['bknight']))
                                break
                        if i=='wrook':
                            if coincount['wrook']<=2:
                                print('the chess board contains %s wrook in chess board'%(coincount['wrook']))
                            else:
                                print('the chess board contains %s wrook in chess board,the chess board is invalid'%(coincount['wrook']))
                                break
                        if i=='brook':
                            if coincount['brook']<=2:
                                print('the chess board contains %s brook in chess board'%(coincount['brook']))
                            else:
                                print('the chess board contains %s brook in chess board,the chess board is invalid'%(coincount['brook']))
                                break
                        if i=='wpawn':
                            if coincount['wpawn']<=8:
                                print('the chess board contains %s wpawn in chess board'%(coincount['wpawn']))
                            else:
                                print('the chess board contains %s wpawn in chess board,the chess board is invalid'%(coincount['wpawn']))
                                break
                        
                        if i=='bpawn':
                            if coincount['bpawn']<=8:
                                print('the chess board contains %s bpawn in chess board'%(coincount['bpawn']))
                            else:
                                print('the chess board contains %s bpawn in chess board,the chess board is invalid'%(coincount['bpawn']))
                                break
                else:
                    print('there are invalid number of kings, the chess board is invalid')
            else:
                print('the white or black king is missing,the chess board is invalid')
                                
                            
                            
            
        
            
    
    
C={'1a':'wking','8a':'bking','8b':'wking','7b':'bpawn','1c':'bpawn'}
ValidChessBoard(C)
# Out:
# ['1a', '8a', '8b', '7b', '1c']
# {'wking': 1}
# {'wking': 1, 'bking': 1}
# {'wking': 2, 'bking': 1}
# {'wking': 2, 'bking': 1, 'bpawn': 1}
# {'wking': 2, 'bking': 1, 'bpawn': 2}
# there are invalid number of kings, the chess board is invalid
